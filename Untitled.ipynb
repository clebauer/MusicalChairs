# %%
import pandas as pd

# %%
attendance_record_raw = pd.read_csv('files/Fall2025.csv')
attendance_record = attendance_record_raw.dropna(subset=["Last Name"])

response_mapping = {'Present':           True,
                    'Absent - notified': False,
                    'Late - notified':   True,
                    'No call, no show':  True}

# %%
pd.unique(attendance_record.iloc[:,6:].values.ravel())
# Out:
# array(['Present', 'Absent - notified', 'Late - notified',
#        'No call, no show'], dtype=object)

# %%
attendance_record
# Out:
#         Last Name First Name    Section      Instrument  \
# 0           Menes     Alyssa  Directors  Music Director
# 2   Andrade Nunez  Stephanie  Woodwinds   Flute/Piccolo
# 3        Erickson      Leann  Woodwinds   Flute/Piccolo
# 4          Farmer      Jerry  Woodwinds           Flute
# 5           Gallo       Dana  Woodwinds           Flute
# ..            ...        ...        ...             ...
# 64      Covington        Ava    Strings           Cello
# 65          Hwang      James    Strings           Cello
# 66         Kunkel        Ben    Strings           Cello
# 67        Vaccari     Carlo*    Strings           Cello
# 68       Verducci        Vin    Strings      Contrabass
#
#    August 24th - Kickoff Rehearsal  August 31st - NO REHEARSAL  \
# 0                          Present                         NaN
# 2                Absent - notified                         NaN
# 3                          Present                         NaN
# ...

# %%
attendance_record.iloc[:,5:]
# Out:
#     August 31st - NO REHEARSAL      September 7th September 14th  \
# 0                          NaN            Present        Present
# 1                          NaN                NaN            NaN
# 2                          NaN            Present        Present
# 3                          NaN            Present        Present
# 4                          NaN            Present        Present
# ..                         ...                ...            ...
# 66                         NaN  Absent - notified        Present
# 67                         NaN            Present        Present
# 68                         NaN  Absent - notified        Present
# 69                         NaN                NaN            NaN
# 70                         NaN                  2              3
#
#        September 21st September 28th October 5th October 12th October 19th  \
# 0             Present        Present     Present      Present      Present
# ...
